# %%
import scanpy as sc

# %%
adata = sc.read("/Users/aneesavalentine/Downloads/a535948e-9281-4ab5-9aa1-26c1490154f3.h5ad")

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col assay_ontology_term_id  \
# AAACAACGAATAGTTC-1          0          0         16            EFO:0010961
# AAACAAGTATCTCCCA-1          1         50        102            EFO:0010961
# AAACAATCTACTAGCA-1          0          3         43            EFO:0010961
# AAACACCAATAACTGC-1          1         59         19            EFO:0010961
# AAACAGAGCGACTCCT-1          1         14         94            EFO:0010961
# ...                       ...        ...        ...                    ...
# TTGTTTCACATCCAGG-1          1         58         42            EFO:0010961
# TTGTTTCATTAGTCTA-1          1         60         30            EFO:0010961
# TTGTTTCCATACAACT-1          1         45         27            EFO:0010961
# TTGTTTGTATTACACG-1          1         73         41            EFO:0010961
# TTGTTTGTGTAAATTC-1          1          7         51            EFO:0010961
#
# ...

# %%
adata.X
# Out:
# <4992x36406 sparse matrix of type '<class 'numpy.float32'>'
# 	with 13639006 stored elements in Compressed Sparse Row format>

# %%
adata.var
# Out:
#                    feature_types  feature_is_filtered       feature_name  \
# gene_ids
# ENSG00000243485  Gene Expression                False        MIR1302-2HG
# ENSG00000237613  Gene Expression                False            FAM138A
# ENSG00000186092  Gene Expression                False              OR4F5
# ENSG00000238009  Gene Expression                False  ENSG00000238009.6
# ENSG00000239945  Gene Expression                False  ENSG00000239945.1
# ...                          ...                  ...                ...
# ENSG00000277836  Gene Expression                False  ENSG00000277836.1
# ENSG00000278633  Gene Expression                False  ENSG00000278633.1
# ENSG00000276017  Gene Expression                False  ENSG00000276017.1
# ENSG00000278817  Gene Expression                False  ENSG00000278817.1
# ENSG00000277196  Gene Expression                False  ENSG00000277196.4
#
#                 feature_reference feature_biotype feature_length  \
# gene_ids
# ...

# %%
# Print all possible values in the 'disease' column
print(adata.obs['disease'].unique())
# Out:
# ['breast carcinoma']
# Categories (1, object): ['breast carcinoma']

# %% [markdown]
# So far, it seems like our dataset only has tumor cells and no healthy cells. Having healthy controls would be ideal, but we can stil infer abberrant splicing patterns by focusing on deviations from expected transcript annotations (e.g., using a reference transcriptome like GENCODE).
#
# Our data also doesn't seem to have any transcript-level annotations (as indicated by the Ensembl gene identifier 'ENS...'), so we'll need to use external references.

# %%
adata_raw = adata.copy()
